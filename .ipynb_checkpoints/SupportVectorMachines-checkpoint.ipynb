# %%
import os
import sklearn
from sklearn import datasets
from sklearn.datasets import make_moons
from sklearn.svm import SVC, SVR, LinearSVC, LinearSVR
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

#To make the notebook's output stable across runs
np.random.seed(42)

#Uses Jupyter's own backend to plot
# %matplotlib inline

#To make pretty figures
mpl.rc("axes", labelsize=14)
mpl.rc("xtick", labelsize=12)
mpl.rc("ytick", labelsize=12)

#Path for saving images 
IMAGES_PATH = os.path.join("images")
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# # Section: Linear SVM Classification

# %% [markdown]
# Support Vector Machine (SVM) is a model, capble of performing linear or nonlinear classification, regression and in some cases even outlier detection. This type of model is typically suited for classification of complex small / medium sized datasets

# %% [markdown]
# ##### Large margin classification

# %% [markdown]
# The fundamental idea of SVM can be illustrated by the Figure 5-1, the left is a "bad" model and the right is a SVM model

# %%
iris = datasets.load_iris()
X = iris["data"][:, (2, 3)] #Petal width and petal length
y = iris["target"]

setosa_or_versicolor = (y == 0) | (y == 1)
X = X[setosa_or_versicolor]
y = y[setosa_or_versicolor]

svm_clf = SVC(kernel="linear", C=float("inf"))
svm_clf.fit(X, y)
# Out:
# SVC(C=inf, kernel='linear')

# %%
#Bad model
x0 = np.linspace(0, 5.5 ,200)
pred_1 = 5 * x0 - 20
pred_2 = x0 - 1.8
pred_3 = 0.1 * x0 + 0.5

def plot_svc_decision_boundary(svm_clf, xmin, xmax):
    w = svm_clf.coef_[0]
    b = svm_clf.intercept_[0]
    
    #At the decision boundry, w0*x0 + w1*x1 + b =0
    # => x1 = -w0/w1 * x0 - b/w1
    x0 = np.linspace(xmin, xmax, 200)
    decision_boundary = -w[0]/w[1] * x0 - b/w[1]
    
    margin = 1/w[1]
    gutter_up = decision_boundary + margin
    gutter_down = decision_boundary - margin
    
    svs = svm_clf.support_vectors_
    plt.scatter(svs[:, 0], svs[:, 1], s=180, facecolors="#FFAAAA")
    plt.plot(x0, decision_boundary, "k-", linewidth=2)
    plt.plot(x0, gutter_up, "k--", linewidth=2)
    plt.plot(x0, gutter_down, "k--", linewidth=2)

fig, axes = plt.subplots(ncols=2, figsize=(10, 2.7), sharey=True)

plt.sca(axes[0])
plt.plot(x0, pred_1, "g--", linewidth=2)
plt.plot(x0, pred_2, "m-", linewidth=2)
plt.plot(x0, pred_3, "r-", linewidth=2)
plt.plot(X[:, 0][y==1], X[:, 1][y==1], "bs", label="Iris versicolor")
plt.plot(X[:, 0][y==0], X[:, 1][y==0], "yo", label="Iris setosa")
plt.xlabel("Petal length", fontsize=14)
plt.ylabel("Petal width", fontsize=14)
plt.legend(loc="upper left", fontsize=14)
plt.axis([0, 5.5, 0, 2])

plt.sca(axes[1])
plot_svc_decision_boundary(svm_clf, 0, 5.5)
plt.plot(X[:, 0][y==1], X[:, 1][y==1], "bs")
plt.plot(X[:, 0][y==0], X[:, 1][y==0], "yo")
plt.xlabel("Petal length", fontsize=14)
plt.axis([0, 5.5, 0, 2])

save_fig("SVM - Large margin classification")
plt.show()
print("Figure 5-1")
# Out:
# Saving figure SVM - Large margin classification
# Figure 5-1

# %% [markdown]
# The <strong>left plot</strong> shows the decision boundaries of 3 linear classifiers. The <em>green line </em>(dashed) is so bad that it doesn't even separate the classes properly. The other <em>two models</em> perform very well on this training set, <strong>but</strong> their decision boundaries are so close to the instances. I.e, they won't perform as well with new instances

# %% [markdown]
# On the <strong>right plot</strong> we can see that the decision boundary (solid line) of the SVM classifier manages to separate the two classes and stay far away from them. It helps to think of the SVM as fitting the widest possible street (represented by the dashed lines) between the classes. This is called <strong><em>large margin classification</em></strong>

# %% [markdown]
# Adding more training instances "off the streets" will not affect the decision boundary: it's full determined (or "supported") by the instances located on the edge of the street. These instances are called <strong><em>support vectors</em></strong> (circled in pink)

# %% [markdown]
# ##### Sensitivity to feature scale

# %% [markdown]
# Figure 5-2 shows how sensitive SVMs are to feature scales. On the <strong>left plot</strong>, the vertical scale (<strong>y axis</strong>) is much larger that the horizontal scale (<strong>x axis</strong>), so the widest possible street is close to the horizontal. <br>
# The <strong>right plot</strong> shows how the decision boundary look much better after feature scaling with StandardScaler()

# %%
Xs = np.array([[1, 50], [5, 20], [3, 80], [5, 60]]).astype(np.float64)
ys = np.array([0, 0, 1, 1])
svm_clf = SVC(kernel="linear", C=100)
svm_clf.fit(Xs, ys)

plt.figure(figsize=(9, 2.7))
plt.subplot(121)
plt.plot(Xs[:,0][ys==1], Xs[:,1][ys==1], "bo")
plt.plot(Xs[:,0][ys==0], Xs[:,1][ys==0], "ms")
plot_svc_decision_boundary(svm_clf, 0, 6)
plt.title("Unscaled", fontsize=16)
plt.xlabel("$x_0$", fontsize=20)
plt.ylabel("$x_1$", rotation=0, fontsize=20)
plt.axis([0, 6, 0, 90])

scaler = StandardScaler()
X_scaled = scaler.fit_transform(Xs)
svm_clf.fit(X_scaled, ys)

plt.subplot(122)
plt.plot(X_scaled[:, 0][ys==1], X_scaled[:, 1][ys==1], "bo")
plt.plot(X_scaled[:, 0][ys==0], X_scaled[:, 1][ys==0], "ms")
plot_svc_decision_boundary(svm_clf, -2, 2)
plt.title("Scaled", fontsize=16)
plt.xlabel("$x_0$", fontsize=20)
plt.ylabel("$x'_1$", rotation=0, fontsize=20)
plt.axis([-2, 2, -2, 2])

save_fig("SVM - Sensitivity to feature scale")
# Out:
# Saving figure SVM - Sensitivity to feature scale

# %% [markdown]
# ##### Soft margin classification

# %% [markdown]
# If we strictly impose on all the instances to be on the right side, off the street, then this is called <strong><em>hard margin classification</em></strong>. There are two main issues with this type of classification:
# <ul>
#     <li>First, it only works if the data is linearly separable</li>
#     <li>Second, its sensitive to outliers</li>
# </ul>

# %% [markdown]
# In Figure 5-3 we add to the Iris dataset one additional outlier. On the <strong>left plot</strong>, it's impossible to find a hard margin. While on the <strong>right plot</strong> the decision boundary ends up with a very narrow street, thus it will most likely not generalize as well

# %%
X_outliers = np.array([[3.4, 1.3], [3.2, 0.8]])
y_outliers = np.array([0, 0])

Xo1 = np.concatenate([X, X_outliers[:1]], axis=0)
yo1 = np.concatenate([y, y_outliers[:1]], axis=0)
Xo2 = np.concatenate([X, X_outliers[1:]], axis=0)
yo2 = np.concatenate([y, y_outliers[1:]], axis=0)

svm_clf2 = SVC(kernel="linear", C=10**9)
svm_clf2.fit(Xo2, yo2)

fig, axes = plt.subplots(ncols=2, figsize=(10, 2.7), sharey=True)

plt.sca(axes[0])
plt.plot(Xo1[:, 0][yo1==1], Xo1[:, 1][yo1==1], "bs")
plt.plot(Xo1[:, 0][yo1==0], Xo1[:, 1][yo1==0], "yo")
plt.text(0.3, 1.0 ,"Impossible!", fontsize=24, color="red")
plt.xlabel("Petal length", fontsize=14)
plt.ylabel("Petal width", fontsize=14)
plt.annotate("Outlier",
             xy=(X_outliers[0][0], X_outliers[0][1]),
             xytext=(2.5, 1.7),
             ha="center",
             arrowprops=dict(facecolor="black", shrink=0.1),
             fontsize=16
            )
plt.axis([0, 5.5, 0, 2])

plt.sca(axes[1])
plt.plot(Xo2[:, 0][yo2==1], Xo2[:, 1][yo2==1], "bs")
plt.plot(Xo2[:, 0][yo2==0], Xo2[:, 1][yo2==0], "yo")
plot_svc_decision_boundary(svm_clf2, 0, 5.5)
plt.xlabel("Petal length", fontsize=14)
plt.annotate("Outlier",
             xy=(X_outliers[1][0], X_outliers[1][1]),
             xytext=(3.2, 0.08),
             ha="center",
             arrowprops=dict(facecolor="black", shrink=0.5),
             fontsize=16
            )
plt.axis([0, 5.5, 0, 2])

save_fig("SVM - Sensitivity to outliers")
plt.show()
print("Figure 5-3")
# Out:
# Saving figure SVM - Sensitivity to outliers
# Figure 5-3

# %% [markdown]
# In order to avoids these issues, a more flexible model is needed. The main goal is to find a good balance between keeping the street as wide as possible and limiting the <em>margin violations</em> (instances that end up on the street or the wrong side). This is called <strong><em>soft margin classification</em></strong>

# %% [markdown]
# ##### Large margin vs fewer margin violations

# %% [markdown]
# Scikit Learn's SVM model has a hyperparameter <em>C</em>, if it's set to a low value then we end up with a model that has a wide street, but might have many <em>margin violations</em>. With a high value for <em>C</em>, we get the opposite - narrow street with less <em>margin violations</em>. In the case of figure 5-4, the <strong>left plot</strong> might have many <em>margin violations</em> but will probably generalize better<br>
# <strong>Note</strong> If your SVM is overfitting, you can regularize it by reducing <em>C</em>

# %% [markdown]
# Let's illustrate this idea

# %%
iris = datasets.load_iris()
X = iris["data"][:, (2, 3)] #Petal width, petal length
y = (iris["target"] == 2).astype(np.float64) #Iris Virginica

svm_clf = Pipeline([
    ("scaler", StandardScaler()),
    ("linear_svc", LinearSVC(C=1, loss="hinge", random_state=42))
])
svm_clf.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('linear_svc', LinearSVC(C=1, loss='hinge', random_state=42))])

# %%
svm_clf.predict([[5.5, 1.7]]) #Target names = array(["setosa", "versicolor", "virginica"])
# Out:
# array([1.])

# %% [markdown]
# <strong>Note</strong>, unlike Logistic regression classifiers, SVM classifiers don't output probabilities for each class

# %%
#Generate the two plots
scaler = StandardScaler()
svm_clf1 = LinearSVC(C=1, loss="hinge", random_state=42)
svm_clf2 = LinearSVC(C=100, loss="hinge", random_state=42)

scaled_svm_clf1 = Pipeline([
        ("scaler", scaler),
        ("linear_svc", svm_clf1)
    ])
scaled_svm_clf2 = Pipeline([
        ("scaler", scaler),
        ("linear_svc", svm_clf2)
    ])

scaled_svm_clf1.fit(X, y)
scaled_svm_clf2.fit(X, y)
# Out:
# C:\Users\Jason\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('linear_svc',
#                  LinearSVC(C=100, loss='hinge', random_state=42))])

# %%
#Convert to unscaled parameters
b1 = svm_clf1.decision_function([-scaler.mean_ / scaler.scale_])
b2 = svm_clf2.decision_function([-scaler.mean_ / scaler.scale_])
w1 = svm_clf1.coef_[0] / scaler.scale_
w2 = svm_clf2.coef_[0] / scaler.scale_
svm_clf1.intercept_ = np.array([b1])
svm_clf2.intercept_ = np.array([b2])
svm_clf1.coef_ = np.array([w1])
svm_clf2.coef_ = np.array([w2])

#Find support vectors (LinearSVC doesn't do it automatically)
t = y * 2 - 1
support_vectors_idx1 = (t * (X.dot(w1) + b1) < 1).ravel()
support_vectors_idx2 = (t * (X.dot(w2) + b2) < 1).ravel()
svm_clf1.support_vectors_ = X[support_vectors_idx1]
svm_clf2.support_vectors_ = X[support_vectors_idx2]

# %%
fig, axes = plt.subplots(ncols=2, figsize=(10, 2.7), sharey=True)

plt.sca(axes[0])
plt.plot(X[:, 0][y==1], X[:, 1][y==1], "g^", label="Iris virginica")
plt.plot(X[:, 0][y==0], X[:, 1][y==0], "bs", label="Iris versicolor")
plot_svc_decision_boundary(svm_clf1, 4, 5.9)
plt.xlabel("Petal length", fontsize=14)
plt.ylabel("Petal width", fontsize=14)
plt.legend(loc="upper left", fontsize=14)
plt.title("$C = {}$".format(svm_clf1.C), fontsize=16)
plt.axis([4, 5.9, 0.8, 2.8])

plt.sca(axes[1])
plt.plot(X[:, 0][y==1], X[:, 1][y==1], "g^")
plt.plot(X[:, 0][y==0], X[:, 1][y==0], "bs")
plot_svc_decision_boundary(svm_clf2, 4, 5.9)
plt.xlabel("Petal length", fontsize=14)
plt.title("$C = {}$".format(svm_clf2.C), fontsize=16)
plt.axis([4, 5.9, 0.8, 2.8])

save_fig("SVM - Large margin vs fewer margin violations")
print("Figure 5-4")
# Out:
# Saving figure SVM - Large margin vs fewer margin violations
# Figure 5-4

# %% [markdown]
# # End Of Section: Linear SVM Classification

# %% [markdown]
# # Section: Nonlinear SVM Classification

# %% [markdown]
# In some cases datasets aren't linearly separable. One approach to handling nonlinear datasets is to add more features, such as polynomial features, which can result in a linearly separable dataset.<br>
# The following <strong>left plot</strong> illustrates a non linear dataset with the feature $x_1$. But adding a second feature $x_2 = (x_1)^2$, will result in a 2D dataset that is linearly separable

# %%
X1D = np.linspace(-4, 4, 9).reshape(-1, 1)
X2D = np.c_[X1D, X1D**2]
y = np.array([0, 0, 1, 1, 1, 1, 1, 0, 0])

plt.figure(figsize=(10, 3))

plt.subplot(121)
plt.grid(True, which="both")
plt.axhline(y=0, color="k")
plt.plot(X1D[:, 0][y==0], np.zeros(4), "bs")
plt.plot(X1D[:, 0][y==1], np.zeros(5), "g^")
plt.gca().get_yaxis().set_ticks([])
plt.xlabel(r"$x_1$", fontsize=20)
plt.axis([-4.5, 4.5, -0.2, 0.2])

plt.subplot(122)
plt.grid(True, which="both")
plt.axhline(y=0, color="k")
plt.axvline(x=0, color="k")
plt.plot(X2D[:, 0][y==0], X2D[:, 1][y==0], "bs")
plt.plot(X2D[:, 0][y==1], X2D[:, 1][y==1], "g^")
plt.xlabel(r"$x_1$", fontsize=20)
plt.ylabel(r"$x_2$", rotation=0, fontsize=20)
plt.gca().get_yaxis().set_ticks([0, 4, 8, 12, 16])
plt.plot([-4.5, 4.5], [6.5, 6.5], "r--", linewidth=3)
plt.axis([-4.5, 4.5, -1, 17])

plt.subplots_adjust(right=1)

save_fig("SVM - Linear vs nonlinear dataset", tight_layout=False)
print("Figure 5-5")
# Out:
# Saving figure SVM - Linear vs nonlinear dataset
# Figure 5-5

# %% [markdown]
# Let's implement a Linear SVM with polynomial features using Scikit Learn

# %%
X, y = make_moons(n_samples=100, noise=0.15, random_state=42)

def plot_datasets(X, y, axes):
    plt.plot(X[:, 0][y==0], X[:, 1][y==0], "bs")
    plt.plot(X[:, 0][y==1], X[:, 1][y==1], "g^")
    plt.axis(axes)
    plt.grid(True, which="both")
    plt.xlabel(r"$x_1$", fontsize=20)
    plt.ylabel(r"$x_2$", rotation=0, fontsize=20)

plot_datasets(X, y, [-1.5, 2.5, -1, 1.5])
plt.show()

# %%
polynomial_svm_clf = Pipeline([
    ("poly_feature", PolynomialFeatures(degree=3)),
    ("scaler", StandardScaler()),
    ("svm_clf", LinearSVC(C=10, loss="hinge", random_state=42))
])

polynomial_svm_clf.fit(X, y)
# Out:
# C:\Users\Jason\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Pipeline(steps=[('poly_feature', PolynomialFeatures(degree=3)),
#                 ('scaler', StandardScaler()),
#                 ('svm_clf', LinearSVC(C=10, loss='hinge', random_state=42))])

# %%
def plot_predictions(clf, axes):
    x0s = np.linspace(axes[0], axes[1], 100)
    x1s = np.linspace(axes[2], axes[3], 100)
    x0, x1 = np.meshgrid(x0s, x1s)
    X = np.c_[x0.ravel(), x1.ravel()]
    y_pred = clf.predict(X).reshape(x0.shape)
    y_decision = clf.decision_function(X).reshape(x0.shape)
    plt.contourf(x0, x1, y_pred, cmap=plt.cm.brg, alpha=0.2)
    plt.contourf(x0, x1, y_decision, cmap=plt.cm.brg, alpha=0.1)
    
plot_predictions(polynomial_svm_clf, [-1.5, 2.5, -1, 1.5])
plot_datasets(X, y, [-1.5, 2.5, -1, 1.5])

save_fig("SVM - Linear SVM using polynomial features")
plt.show()
print("Figure 5-6")
# Out:
# Saving figure SVM - Linear SVM using polynomial features
# Figure 5-6

# %% [markdown]
# ##### Polynomial kernel

# %% [markdown]
# Adding a <strong>low polynomial degree</strong> to a machine learning algorithm, means that it won't be able to handle complex datasets, while a <strong>high polynomial degree</strong> creates a very large number of features, making the model very slow

# %% [markdown]
# The trick around that is using a mathematical technique called <strong><em>kernel trick<em></strong>. It makes it possible to achieve the same result if you added many polynomial features without having to calculate them. I.e, there is no combinatorial explosion of the number of features

# %% [markdown]
# Let's impliment the <strong><em>kernel trick<em></strong> with the SVC

# %%
poly_kernel_svm_clf = Pipeline([
    ("scaler", StandardScaler()),
    ("svm_clf", SVC(kernel="poly", degree=3, coef0=1, C=5))
])
poly_kernel_svm_clf.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm_clf', SVC(C=5, coef0=1, kernel='poly'))])

# %%
poly100_kernel_svm_clf = Pipeline([
    ("scaler", StandardScaler()),
    ("svm_clf", SVC(kernel="poly", degree=10, coef0=100, C=5))
])
poly100_kernel_svm_clf.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm_clf', SVC(C=5, coef0=100, degree=10, kernel='poly'))])

# %%
fig, axes = plt.subplots(ncols=2, figsize=(10.5, 4), sharey=True)

plt.sca(axes[0])
plot_predictions(poly_kernel_svm_clf, [-1.5, 2.5, -1, 1.5])
plot_datasets(X, y, [-1.5, 2.5, -1, 1.5])
plt.title(r"$d=3$, $r=1$, $C=5$", fontsize=20)

plt.sca(axes[1])
plot_predictions(poly100_kernel_svm_clf, [-1.5, 2.5, -1, 1.5])
plot_datasets(X, y, [-1.5, 2.5, -1, 1.5])
plt.title(r"$d=10$, $r=100$, $C=5$", fontsize=20)
plt.ylabel("")

save_fig("SVM - SVM classifier with a polynomial kernel")
print("Figure 5-7")
# Out:
# Saving figure SVM - SVM classifier with a polynomial kernel
# Figure 5-7

# %% [markdown]
# <strong>Note</strong>, if your model is <strong>overfitting</strong>, then you might want to <strong>decrease</strong> the polynomial degree. Conversely, if it's <strong>underfitting</strong>, try <strong>increasing</strong> it. The hyperparameter <em>coef0</em> controls how much your model is influenced by high/low degree polynomials. <br>
# In order to find the right hyperparametes values, use <strong>grid search</strong>. Start with a coarse grid search, then a finer search around the best values found. Additionally, knowing what each parameter does can help you search in the right part of the hyperparameter space

# %% [markdown]
# ##### Similarity features

# %% [markdown]
# Another way to tackle nonlinear problems is to add features that are computed using a <em>similarity function</em>, which measures how much an instance resembles a particular <em>landmark</em>

# %% [markdown]
# Let's illustrate this with a plot

# %%
def gaussian_rbf(x, landmark, gamma):
    return np.exp(-gamma * np.linalg.norm(x - landmark, axis=1)**2)

gamma = 0.3

x1s = np.linspace(-4.5, 4.5, 200).reshape(-1, 1)
x2s = gaussian_rbf(x1s, -2, gamma)
x3s = gaussian_rbf(x1s, 1, gamma)

XK = np.c_[gaussian_rbf(X1D, -2, gamma), gaussian_rbf(X1D, 1, gamma)]
yk = np.array([0, 0, 1, 1, 1, 1, 1, 0 ,0])

plt.figure(figsize=(10.5, 4))

plt.subplot(121)
plt.grid(True, which="both")
plt.axhline(y=0, color="k")
plt.scatter(x=[-2, 1], y=[0, 0], s=150, alpha=0.5, c="red")
plt.plot(X1D[:, 0][yk==0], np.zeros(4), "bs")
plt.plot(X1D[:, 0][yk==1], np.zeros(5), "g^")
plt.plot(x1s, x2s, "g--")
plt.plot(x1s, x3s, "b:")
plt.gca().get_yaxis().set_ticks([0, 0.25, 0.5, 0.75, 1])
plt.xlabel(r"$x_1$", fontsize=20)
plt.ylabel(r"Similarity", fontsize=14)
plt.annotate(r"$\mathbf{x}$",
             xy=(X1D[3, 0], 0),
             xytext=(-0.5, 0.2),
             ha="center",
             arrowprops=dict(facecolor="black", shrink=0.1),
             fontsize=18)
plt.text(-2, 0.9, "$x_2$", ha="center", fontsize=20)
plt.text(1, 0.9, "$x_3$", ha="center", fontsize=20)
plt.axis([-4.5, 4.5, -0.1, 1.1])

plt.subplot(122)
plt.grid(True, which='both')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.plot(XK[:, 0][yk==0], XK[:, 1][yk==0], "bs")
plt.plot(XK[:, 0][yk==1], XK[:, 1][yk==1], "g^")
plt.xlabel(r"$x_2$", fontsize=20)
plt.ylabel(r"$x_3$  ", rotation=0, fontsize=20)
plt.annotate(r"$\phi\left(\mathbf{x}\right)$",
            xy=(XK[3, 0], XK[3, 1]),
            xytext=(0.65, 0.5),
            ha="center",
            arrowprops=dict(facecolor="black", shrink=0.1),
            fontsize=18)
plt.plot([-0.1, 1.1], [0.57, -0.1], "r--", linewidth=3)
plt.axis([-0.1, 1.1, -0.1, 1.1])

plt.subplots_adjust(right=1)

save_fig("SVM - Similarity features using the Gaussian RBF")
plt.show()
print("Figure 5-8")
# Out:
# Saving figure SVM - Similarity features using the Gaussian RBF
# Figure 5-8

# %% [markdown]
# The <strong>left plot</strong> shows a dataset in which we added two landmarks at $x_1$ = -2 and $x_1$ = 1. Next, we define the similarity function to be the Gaussian <em>Radial Basis Function(RBF)</em> with $\gamma$ = 0.3, as seen in the following equation

# %% [markdown]
# <img src="images/SVM - gaussian rbf equation.png">

# %% [markdown]
# The output is a bell shaped function (gaussian = normal) varying from 0 (very far away from the landmark) to 1 (at the landmark).<br>
# Let's compute the instance $x_1$ = -1: located at a distance of 1 from the first landmark ($x_2$) and 2 from the second landmark ($x_3$).<br>
# Thus, its new feature are $x_2$ = $exp\left(-0.3 \times 1^2\right) \approx 0.74$ and $x_3$ = $exp\left(-0.3 \times 2^2\right) \approx 0.3$. The plot to the right shows the transformed dataset (without the original features), which is now linearly separable

# %%
x1_example = X1D[3, 0] #=> -1.0
for landmark in (-2, 1):
    k = gaussian_rbf(np.array([[x1_example]]), np.array([[landmark]]), gamma)
    print("Phi({}, {}) = {}".format(x1_example, landmark, k))
# Out:
# Phi(-1.0, -2) = [0.74081822]
# Phi(-1.0, 1) = [0.30119421]

# %% [markdown]
# <strong>How to select landmarks?</strong> The simples solution is to create a landmark at the location of each instance. Consequently, creating many dimensions that will increase the chances of the transformed training set to be linearly separable.<br>
# The <strong>downside</strong> is that a training set with <em>m</em> instances and <em>n</em> features will be transformed into a training set with <em>m</em> instances and features (assuming the original features have been dropped). Thus, if the training set is very large, you end up with an equal number of features

# %% [markdown]
# ##### Gaussian RBF kernel

# %% [markdown]
# Just like the polynomial features method in SVC (kernel="poly"), the Gaussian RBF can be implemented in SVC as well using the kernel trick (kernel="rbf")

# %%
rbf_svm_clf = Pipeline([
    ("scaler", StandardScaler()),
    ("svm_clf", SVC(kernel="rbf", gamma=5 , C=0.001))
])
rbf_svm_clf.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm_clf', SVC(C=0.001, gamma=5))])

# %% [markdown]
# Let's illustrate SVC with RBF kernl and different values of the hyperparameters, $\gamma$ and C

# %%
gamma1, gamma2 = 0.1, 5
C1, C2 = 0.001, 1000
hyperparams = (gamma1, C1), (gamma1, C2), (gamma2, C1), (gamma2, C2)

svm_clfs = []
for gamma, C in hyperparams:
    rbf_kernel_svm_clf = Pipeline([
        ("scaler", StandardScaler()),
        ("svm_clf", SVC(kernel="rbf", gamma=gamma, C=C))
    ])
    rbf_kernel_svm_clf.fit(X, y)
    svm_clfs.append(rbf_kernel_svm_clf)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10.5, 7), sharex=True,
                         sharey=True)

for i, svm_clf in enumerate(svm_clfs):
    plt.sca(axes[i // 2, i % 2])
    plot_predictions(svm_clf, [-1.5, 2.5, -1, 1.5])
    plot_datasets(X, y, [-1.5, 2.5, -1, 1.5])
    gamma, C = hyperparams[i]
    plt.title("$\gamma$ = {}, C = {}".format(gamma, C), fontsize=16)
    if i in (0, 1):
        plt.xlabel("")
    if i in (1, 3):
        plt.ylabel("")
        
save_fig("SVM - Classifiers using RGB kernel with different hyperparameters")
plt.show()
print("Figure 5-9")
# Out:
# Saving figure SVM - Classifiers using RGB kernel with different hyperparameters
# Figure 5-9

# %% [markdown]
# We can see that:
# <ul>
#     <li>Increasing $\gamma$ makes the bell-shaped curve narrower. Which means that instances range of influence is smaller: decision boundary is more irregular.</li>
#     <li>On the other side, small $\gamma$ makes the bell-shaped curve wider. Instances have a larger range of influence: decision boundary is smoother</li>
# </ul>
# This means that $\gamma$ acts as a <strong>regularization</strong> hyperparameter: if the model is overfitting -> reduce $\gamma$, if it's underfitting -> increase it

# %% [markdown]
# <strong>Which kernel to use?</strong><br>
# Use <em>linear</em> kernel first, especially if the training set is very large or has plenty of features (side note, LinearSVC is much faster than SVC(kernel="linear")). If the training set isn't too large, try <em>Gaussian RBF</em> kernel. <br>
# Lastly, if you have more time and computational power, experiment with other kernels, using cross-validation and grid search

# %% [markdown]
# ##### Computational complexity

# %% [markdown]
# The <strong>LinearSVC</strong> class is based on the liblinear library, which implements an optimized algorithm for linear SVMs. It doesn't support the linear trick, yet it scales almost linearly with the number of training instances and the number of features
# <br>
# The algorithm takes longer if your require a very high precision. This is controlled by the tolerance hyperparameter $\epsilon$ (tol in Scikit Learn)
# <br>
# The <strong>SVC</strong> class is based on the libsvm library, which implements an algorithm that supports the kernel trick. When the number of training instances is large (e.g hundreds of thousands), it gets very slow. Thus, it's well suited for complex small or medium sized training sets

# %% [markdown]
# <img src="images/SVM - Comparison of Scikit Learn's classes for SVM classification.png">

# %% [markdown]
# # End Of Section: Nonlinear SVM Classification

# %% [markdown]
# # Section: SVM Regression

# %% [markdown]
# The difference betweem SVM for classification and regression are their objectives:
# <ul>
#     <li><strong>Classification:</strong> Fit the largest street between two classes while limiting margin violations</li>
#     <li><strong>Regression:</strong> Fit as many instances as possible ON the street while limiting the margin violations. The width of the street is controlled by the hyperparameter $\epsilon$</li>
# </ul>

# %% [markdown]
# Let's illustrate a SVM regression with a large margin and a small margin

# %%
np.random.seed(42)
m = 50
X = 2 * np.random.rand(m, 1)
y = (4 + 3 * X + np.random.randn(m, 1)).ravel()

svm_reg = LinearSVR(epsilon=1.5, random_state=42)
svm_reg.fit(X, y)
# Out:
# LinearSVR(epsilon=1.5, random_state=42)

# %%
svm_reg1 = LinearSVR(epsilon=1.5, random_state=42)
svm_reg2 = LinearSVR(epsilon=0.5, random_state=42)
svm_reg1.fit(X, y)
svm_reg2.fit(X, y)

def find_support_vectors(svm_reg, X, y):
    y_pred = svm_reg.predict(X)
    off_margin = (np.abs(y - y_pred) >= svm_reg.epsilon)
    return np.argwhere(off_margin)

svm_reg1.support_ = find_support_vectors(svm_reg1, X, y)
svm_reg2.support_ = find_support_vectors(svm_reg2, X, y)

eps_x1 = 1
eps_y_pred = svm_reg1.predict([[eps_x1]])

# %%
def plot_svm_regression(svm_reg, X, y, axes):
    x1s = np.linspace(axes[0], axes[1], 100).reshape(100, 1)
    y_pred = svm_reg.predict(x1s)
    plt.plot(x1s, y_pred, "k-", linewidth=2, label=r"$\hat{y}$")
    plt.plot(x1s, y_pred + svm_reg.epsilon, "k--")
    plt.plot(x1s, y_pred - svm_reg.epsilon, "k--")
    plt.scatter(X[svm_reg.support_], y[svm_reg.support_], s=180,
                facecolors="#ffaaaa")
    plt.plot(X, y, "bo")
    plt.legend(loc="upper left", fontsize=18)
    plt.xlabel(r"$x_1$", fontsize=18)
    plt.axis(axes)

fig, axes = plt.subplots(ncols=2, figsize=(9, 4), sharey=True)
plt.sca(axes[0])
plot_svm_regression(svm_reg1, X, y, [0, 2, 3, 11])
plt.title(r"$\epsilon$ = {}".format(svm_reg1.epsilon), fontsize=18)
plt.ylabel(r"$y$", rotation=0, fontsize=18)
plt.annotate(
    "",
    xy=(eps_x1, eps_y_pred),
    xycoords="data",
    xytext=(eps_x1, eps_y_pred - svm_reg1.epsilon),
    textcoords="data",
    arrowprops={"arrowstyle": "<->", "linewidth": 1.5}
)
plt.text(0.91, 5.6, r"$\epsilon$", fontsize=20)

plt.sca(axes[1])
plot_svm_regression(svm_reg2, X, y, [0, 2, 3, 11])
plt.title(r"$\epsilon$ = {}".format(svm_reg2.epsilon), fontsize=18)

save_fig("SVM - SVM regression with large or small margin(epsilon)")
plt.show()
print("Figure 5-10")
# Out:
# Saving figure SVM - SVM regression with large or small margin(epsilon)
# Figure 5-10

# %% [markdown]
# Adding more training instances within the margin doesn't affect the model's predictions, thus, the model is <em>$\epsilon$-sensitive</em>

# %% [markdown]
# When encountered with a nonlinear regression task, you can use a kernelized SVM model. The following plot shows a SVM regression on a random quadratic training set, using a second degree polynomial kernel.
# <ul>
#     <li>The <strong>left plot</strong> shows little regularization - large C value</li>
#     <li>While the <strong>right plot</strong> shows more regularization - smaller C value</li>
# </ul>

# %%
np.random.seed(42)
m = 100
X = 2 * np.random.rand(m, 1) - 1
y = (0.2 + 0.1 * X + 0.5 * X**2 + np.random.randn(m, 1)/10).ravel()

# %%
svm_poly_reg = SVR(kernel="poly", degree=2, C=100, epsilon=0.1, gamma="scale")
svm_poly_reg.fit(X, y)
# Out:
# SVR(C=100, degree=2, kernel='poly')

# %%
svm_poly_reg1 = SVR(kernel="poly", degree=2, C=100, epsilon=0.1, gamma="scale")
svm_poly_reg2 = SVR(kernel="poly", degree=2, C=0.01, epsilon=0.1, gamma="scale")
svm_poly_reg1.fit(X, y)
svm_poly_reg2.fit(X, y)
# Out:
# SVR(C=0.01, degree=2, kernel='poly')

# %%
fig, axes = plt.subplots(ncols=2, figsize=(9, 4), sharey=True)

plt.sca(axes[0])
plot_svm_regression(svm_poly_reg1, X, y, [-1, 1, 0, 1])
plt.title(r"degree = {}, C = {}, $\epsilon$ = {}".format(svm_poly_reg1.degree,
                                                         svm_poly_reg1.C,
                                                         svm_poly_reg1.epsilon),
          fontsize=18)
plt.ylabel(r"$y$", rotation=0, fontsize=18)

plt.sca(axes[1])
plot_svm_regression(svm_poly_reg2, X, y, [-1, 1, 0, 1])
plt.title(r"degree = {}, C = {}, $\epsilon$ = {}".format(svm_poly_reg2.degree,
                                                          svm_poly_reg2.C,
                                                          svm_poly_reg2.epsilon),
          fontsize=18)

save_fig("SVM - SVM regression with polynomial kernel")
plt.show()
print("Figure 5-11")
# Out:
# Saving figure SVM - SVM regression with polynomial kernel
# Figure 5-11

# %% [markdown]
# SVC class for regression -> SVR class - both scale linearly with the size of the training set<br>
# LinearSVC class for regression -> Linear SVR -  both get slow when training set grows

# %% [markdown]
# # End Of Section: SVM Regression

# %% [markdown]
# # Section: Under The Hood

# %% [markdown]
# In this seciton we'll look at how SVMs make predictions and how their training alogirithms work. We'll start with linear SVM classifier

# %% [markdown]
# ##### Decision function and predictions

# %% [markdown]
# The linear SVM classifier model predicts the class of a new instance $x$ by computing the decision function $w^Tx + b = w_1x_1 + ... + w_nx_n + b$. If the result is positive the predicted class $\hat{y}$ is the possitive class (1), otherwise it's the negative class (0)

# %% [markdown]
# <img src="images/SVM - Under the hood of linear svm prediction.png">
